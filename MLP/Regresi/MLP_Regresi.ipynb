# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# load dataset
dataframe = pandas.read_csv("/content/drive/MyDrive/TugasJST/MLP/Regresi/housing.csv", delim_whitespace=True, header=None)
dataset = dataframe.values
# split into input (X) and output (Y) variables
X = dataset[:,0:13]
Y = dataset[:,13]

# %%
# define base model
def baseline_model():
	# create model
	model = Sequential()
	model.add(Dense(13, input_dim=13, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model

# %%
model = baseline_model()
model.save("house_mlp.h5")

# %%
#Result
# evaluate model
estimator = KerasRegressor(build_fn=baseline_model, epochs=25, batch_size=5, verbose=1)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Epoch 1/25
# 91/91 [==============================] - 0s 971us/step - loss: 531.9627
# Epoch 2/25
# 91/91 [==============================] - 0s 1ms/step - loss: 114.1960
# Epoch 3/25
# 91/91 [==============================] - 0s 1ms/step - loss: 69.8693
# Epoch 4/25
# 91/91 [==============================] - 0s 1ms/step - loss: 72.3559
# Epoch 5/25
# 91/91 [==============================] - 0s 1ms/step - loss: 64.8090
# Epoch 6/25
# 91/91 [==============================] - 0s 994us/step - loss: 68.5598
# Epoch 7/25
# 91/91 [==============================] - 0s 991us/step - loss: 54.5992
# Epoch 8/25
# 91/91 [==============================] - 0s 1ms/step - loss: 66.4264
# Epoch 9/25
# 91/91 [==============================] - 0s 1ms/step - loss: 63.1753
# Epoch 10/25
# 91/91 [==============================] - 0s 1ms/step - loss: 51.6905
# Epoch 11/25
# 91/91 [==============================] - 0s 1ms/step - loss: 51.0748
# Epoch 12/25
# ...
